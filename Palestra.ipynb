# %% [markdown]
# ## iniciação em coleta de dados Twiiter
# Newton Galiza

# %% [markdown]
# ## Imports Necessários

# %%
import tweepy
from tweepy import OAuthHandler
import json

# %% [markdown]
# ## Autenticação

# %%
consumer_key = "XGS8Xv1y0pWZXyXSHu6c1AVvm"
consumer_secret = "BtzEcusIP67kLJRN7E8xONDwjYwEyASlTXTGxz1jlSbfPkLPes"
access_token = "843892947909332998-SH4Isk6tITrF3Lvku5aNMrP2xWQswrB"
access_secret = "OwmlEjXOcJ8hjauzikRmAYflBInJVYJNcy11MzDYdPwti"

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %% [markdown]
# ## Lendo a TimeLine

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    print(status.text)
# Out:
# Inscrições: https://t.co/OWE6rGwCY9 https://t.co/asuelgTqey
# Acordar no meio da noite com calor é um problema.
# https://t.co/15OIiu1LeG
# "Sempre que temos algo, que antes nos era tão impossível de consquistar, nós acabamos por querer algo que é mais im… https://t.co/eJpUwPibwV
# RT @mozilla: “My whole story doesn’t exist without a free and open Internet.” — @matt___nelson of @dog_rates in our special #netneutrality…
# Meetup sobre Python - PUG-PB https://t.co/1AFHQRq8ll
# “Depois dos 10.” @MarcelFox https://t.co/9ZQKSLKL4A
# Bom reencontrar os amigos e saber que podemos contar uns com os outros pra vida! 😀 https://t.co/QVtmKbCcjA
# #NFLnaESPN  Curtindo aqui em João Pessoa-PB essa transmissão. Quando vai passar algum jogo do meu 49ers??
# RT @MrAmlice: Gunlock. The little arcadey shooter hopper game @zminusone and I worked on is finally out on steam, you can nab it for less t…

# %% [markdown]
# ## Processando o JSON

# %%
for status in tweepy.Cursor(api.home_timeline).items(1):
    print(status._json)
# Out:
# {'source': '<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>', 'possibly_sensitive': False, 'geo': None, 'truncated': False, 'favorited': False, 'retweeted': False, 'user': {'geo_enabled': False, 'has_extended_profile': False, 'following': False, 'profile_sidebar_border_color': 'C0DEED', 'profile_text_color': '333333', 'protected': False, 'default_profile': True, 'profile_link_color': '1DA1F2', 'profile_background_image_url_https': None, 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'contributors_enabled': False, 'listed_count': 0, 'entities': {'url': {'urls': [{'url': 'https://t.co/29TrtNsYc1', 'expanded_url': 'http://github.com/newtongaliza', 'indices': [0, 23], 'display_url': 'github.com/newtongaliza'}]}, 'description': {'urls': []}}, 'favourites_count': 1, 'url': 'https://t.co/29TrtNsYc1', 'description': '', 'created_at': 'Mon Mar 20 18:32:12 +0000 2017', 'is_translation_enabled': False, 'profile_use_background_image': True, 'default
# ...

# %% [markdown]
# ## Lista de Followers

# %%
for friend in tweepy.Cursor(api.friends).items():
    print('FOLLOWERS:\n', friend._json)
# Out:
# FOLLOWERS:
# ...

# %% [markdown]
# ## Listar os Tweets

# %%
for tweet in tweepy.Cursor(api.user_timeline).items():
    print('TWEET:\n', tweet._json)
# Out:
# TWEET:
# ...

# %% [markdown]
# ## Filtragens

# %%
for tweet in tweepy.Cursor(api.user_timeline).items():
    print('TWEET:')
    print(tweet._json['source'])
# Out:
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# <a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>
# TWEET:
# ...

# %% [markdown]
# ## Streaming API

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

from tweepy import OAuthHandler
 
consumer_key = "XGS8Xv1y0pWZXyXSHu6c1AVvm"
consumer_secret = "BtzEcusIP67kLJRN7E8xONDwjYwEyASlTXTGxz1jlSbfPkLPes"
access_token = "843892947909332998-SH4Isk6tITrF3Lvku5aNMrP2xWQswrB"
access_secret = "OwmlEjXOcJ8hjauzikRmAYflBInJVYJNcy11MzDYdPwti"

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 

class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#PUGPB'])

# %% [markdown]
# ## Polindo o código

# %%
def process_or_store(tweet):
    print(json.dumps(tweet))

for friend in tweepy.Cursor(api.friends).items():
    process_or_store(friend._json)
# Out:
# {"status": {"source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "geo": null, "truncated": false, "in_reply_to_user_id_str": null, "contributors": null, "in_reply_to_status_id": null, "is_quote_status": false, "retweet_count": 0, "in_reply_to_user_id": null, "lang": "pt", "favorite_count": 0, "entities": {"hashtags": [{"indices": [0, 10], "text": "NFLnaESPN"}], "user_mentions": [], "urls": [], "symbols": []}, "in_reply_to_screen_name": null, "retweeted": false, "created_at": "Fri Dec 08 03:27:34 +0000 2017", "coordinates": null, "id": 938973297299124232, "place": null, "id_str": "938973297299124232", "favorited": false, "text": "#NFLnaESPN  Curtindo aqui em Jo\u00e3o Pessoa-PB essa transmiss\u00e3o. Quando vai passar algum jogo do meu 49ers??", "in_reply_to_status_id_str": null}, "profile_sidebar_border_color": "BDDCAD", "follow_request_sent": false, "profile_sidebar_fill_color": "DDFFCC", "is_translator": false, "listed_count": 6, "en
# ...
